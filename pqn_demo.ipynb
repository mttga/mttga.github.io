# %% [markdown]
# <a href="https://colab.research.google.com/github/mttga/mttga.github.io/blob/main/pqn_demo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Jax PureGPU Training of PQN in MinAtar

# %% [markdown]
# In this section we're going to train PQN in a single Pure-GPU regime using Jax. We're going to use gymnax version of Minatar in order to run the vectorized environment in gpu. Thanks to Jax vectorization, we will be able to run multiple runs with different random seeds in parallel. The implementation is copied from the original PQN repository: https://github.com/mttga/purejaxql/blob/main/purejaxql/pqn_gymnax.py

# %%
# make sure to install gymanx
# !pip install gymnax==0.0.6
# Out:
# Collecting gymnax==0.0.6
#   Downloading gymnax-0.0.6-py3-none-any.whl.metadata (19 kB)
# Requirement already satisfied: jax in /usr/local/lib/python3.11/dist-packages (from gymnax==0.0.6) (0.4.33)
# Requirement already satisfied: jaxlib in /usr/local/lib/python3.11/dist-packages (from gymnax==0.0.6) (0.4.33)
# Requirement already satisfied: chex in /usr/local/lib/python3.11/dist-packages (from gymnax==0.0.6) (0.1.88)
# Requirement already satisfied: flax in /usr/local/lib/python3.11/dist-packages (from gymnax==0.0.6) (0.10.3)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.11/dist-packages (from gymnax==0.0.6) (6.0.2)
# Collecting gym>=0.26 (from gymnax==0.0.6)
#   Downloading gym-0.26.2.tar.gz (721 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 721.7/721.7 kB 11.8 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: numpy>=1.18.0 in /usr/local/lib/python3.11/dist-packages (from gym>=0.26->gymnax==0.0.6) (1.26.4)
# Requirement already satisfied: cloudpickle>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from gym>=0.26->gymnax==0.0.6) (3.1.1)
# Requirement already satisfied: gym_notices>=0.0.4 in /usr/local/lib/python3.11/dist-packages (from gym>=0.26->gymnax==0.0.6) (0.0.8)
# Requirement already satisfied: absl-py>=0.9.0 in /usr/local/lib/python3.11/dist-packages (from chex->gymnax==0.0.6) (1.4.0)
# Requirement already satisfied: typing_extensions>=4.2.0 in /usr/local/lib/python3.11/dist-packages (from chex->gymnax==0.0.6) (4.12.2)
# Requirement already satisfied: toolz>=0.9.0 in /usr/local/lib/python3.11/dist-packages (from chex->gymnax==0.0.6) (0.12.1)
# Requirement already satisfied: ml-dtypes>=0.2.0 in /usr/local/lib/python3.11/dist-packages (from jax->gymnax==0.0.6) (0.4.1)
# Requirement already satisfied: opt-einsum in /usr/local/lib/python3.11/dist-packages (from jax->gymnax==0.0.6) (3.4.0)
# Requirement already satisfied: scipy>=1.10 in /usr/local/lib/python3.11/dist-packages (from jax->gymnax==0.0.6) (1.13.1)
# Requirement already satisfied: msgpack in /usr/local/lib/python3.11/dist-packages (from flax->gymnax==0.0.6) (1.1.0)
# Requirement already satisfied: optax in /usr/local/lib/python3.11/dist-packages (from flax->gymnax==0.0.6) (0.2.4)
# Requirement already satisfied: orbax-checkpoint in /usr/local/lib/python3.11/dist-packages (from flax->gymnax==0.0.6) (0.6.4)
# Requirement already satisfied: tensorstore in /usr/local/lib/python3.11/dist-packages (from flax->gymnax==0.0.6) (0.1.71)
# Requirement already satisfied: rich>=11.1 in /usr/local/lib/python3.11/dist-packages (from flax->gymnax==0.0.6) (13.9.4)
# Requirement already satisfied: treescope>=0.1.7 in /usr/local/lib/python3.11/dist-packages (from flax->gymnax==0.0.6) (0.1.9)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.11/dist-packages (from rich>=11.1->flax->gymnax==0.0.6) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.11/dist-packages (from rich>=11.1->flax->gymnax==0.0.6) (2.18.0)
# Requirement already satisfied: etils[epy] in /usr/local/lib/python3.11/dist-packages (from optax->flax->gymnax==0.0.6) (1.12.0)
# Requirement already satisfied: nest_asyncio in /usr/local/lib/python3.11/dist-packages (from orbax-checkpoint->flax->gymnax==0.0.6) (1.6.0)
# Requirement already satisfied: protobuf in /usr/local/lib/python3.11/dist-packages (from orbax-checkpoint->flax->gymnax==0.0.6) (4.25.6)
# Requirement already satisfied: humanize in /usr/local/lib/python3.11/dist-packages (from orbax-checkpoint->flax->gymnax==0.0.6) (4.11.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.11/dist-packages (from markdown-it-py>=2.2.0->rich>=11.1->flax->gymnax==0.0.6) (0.1.2)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from etils[epath,epy]->orbax-checkpoint->flax->gymnax==0.0.6) (2024.10.0)
# Requirement already satisfied: importlib_resources in /usr/local/lib/python3.11/dist-packages (from etils[epath,epy]->orbax-checkpoint->flax->gymnax==0.0.6) (6.5.2)
# Requirement already satisfied: zipp in /usr/local/lib/python3.11/dist-packages (from etils[epath,epy]->orbax-checkpoint->flax->gymnax==0.0.6) (3.21.0)
# Downloading gymnax-0.0.6-py3-none-any.whl (92 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 92.4/92.4 kB 3.0 MB/s eta 0:00:00
# Building wheels for collected packages: gym
#   Building wheel for gym (pyproject.toml) ... done
#   Created wheel for gym: filename=gym-0.26.2-py3-none-any.whl size=827692 sha256=40ec3b96052fec1f1990a291a843d304ca470fc885cffc11af522398c8fbe835
#   Stored in directory: /root/.cache/pip/wheels/1c/77/9e/9af5470201a0b0543937933ee99ba884cd237d2faefe8f4d37
# Successfully built gym
# Installing collected packages: gym, gymnax
#   Attempting uninstall: gym
#     Found existing installation: gym 0.25.2
#     Uninstalling gym-0.25.2:
#       Successfully uninstalled gym-0.25.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# dopamine-rl 4.1.2 requires gym<=0.25.2, but you have gym 0.26.2 which is incompatible.
# Successfully installed gym-0.26.2 gymnax-0.0.6

# %%
import jax
import jax.numpy as jnp
import numpy as np
from functools import partial
from typing import Any
import gymnax

import wandb
import chex
import optax
import flax.linen as nn
from flax.training.train_state import TrainState
from gymnax.wrappers.purerl import FlattenObservationWrapper, LogWrapper


class CNN(nn.Module):

    norm_type: str = "layer_norm"

    @nn.compact
    def __call__(self, x: jnp.ndarray, train: bool):

        if self.norm_type == "layer_norm":
            normalize = lambda x: nn.LayerNorm()(x)
        elif self.norm_type == "batch_norm":
            normalize = lambda x: nn.BatchNorm(use_running_average=not train)(x)
        else:
            normalize = lambda x: x

        x = nn.Conv(
            16,
            kernel_size=(3, 3),
            strides=1,
            padding="VALID",
            kernel_init=nn.initializers.he_normal(),
        )(x)
        x = normalize(x)
        x = nn.relu(x)
        x = x.reshape((x.shape[0], -1))
        x = nn.Dense(128, kernel_init=nn.initializers.he_normal())(x)
        x = normalize(x)
        x = nn.relu(x)
        return x


class QNetwork(nn.Module):
    action_dim: int
    norm_type: str = "layer_norm"
    norm_input: bool = False

    @nn.compact
    def __call__(self, x: jnp.ndarray, train: bool):
        if self.norm_input:
            x = nn.BatchNorm(use_running_average=not train)(x)
        else:
            # dummy normalize input for global compatibility
            x_dummy = nn.BatchNorm(use_running_average=not train)(x)
            x = x / 255.0
        x = CNN(norm_type=self.norm_type)(x, train)
        x = nn.Dense(self.action_dim)(x)
        return x


@chex.dataclass(frozen=True)
class Transition:
    obs: chex.Array
    action: chex.Array
    reward: chex.Array
    done: chex.Array
    next_obs: chex.Array
    q_val: chex.Array


class CustomTrainState(TrainState):
    batch_stats: Any
    timesteps: int = 0
    n_updates: int = 0
    grad_steps: int = 0


def make_train(config):

    config["NUM_UPDATES"] = (
        config["TOTAL_TIMESTEPS"] // config["NUM_STEPS"] // config["NUM_ENVS"]
    )

    config["NUM_UPDATES_DECAY"] = (
        config["TOTAL_TIMESTEPS_DECAY"] // config["NUM_STEPS"] // config["NUM_ENVS"]
    )

    assert (config["NUM_STEPS"] * config["NUM_ENVS"]) % config[
        "NUM_MINIBATCHES"
    ] == 0, "NUM_MINIBATCHES must divide NUM_STEPS*NUM_ENVS"

    env, env_params = gymnax.make(config["ENV_NAME"])
    env = LogWrapper(env)
    config["TEST_NUM_STEPS"] = env_params.max_steps_in_episode

    vmap_reset = lambda n_envs: lambda rng: jax.vmap(env.reset, in_axes=(0, None))(
        jax.random.split(rng, n_envs), env_params
    )
    vmap_step = lambda n_envs: lambda rng, env_state, action: jax.vmap(
        env.step, in_axes=(0, 0, 0, None)
    )(jax.random.split(rng, n_envs), env_state, action, env_params)

    # epsilon-greedy exploration
    def eps_greedy_exploration(rng, q_vals, eps):
        rng_a, rng_e = jax.random.split(
            rng
        )  # a key for sampling random actions and one for picking
        greedy_actions = jnp.argmax(q_vals, axis=-1)
        chosed_actions = jnp.where(
            jax.random.uniform(rng_e, greedy_actions.shape)
            < eps,  # pick the actions that should be random
            jax.random.randint(
                rng_a, shape=greedy_actions.shape, minval=0, maxval=q_vals.shape[-1]
            ),  # sample random actions,
            greedy_actions,
        )
        return chosed_actions

    def train(rng):

        original_rng = rng[0]

        eps_scheduler = optax.linear_schedule(
            config["EPS_START"],
            config["EPS_FINISH"],
            (config["EPS_DECAY"]) * config["NUM_UPDATES_DECAY"],
        )

        lr_scheduler = optax.linear_schedule(
            init_value=config["LR"],
            end_value=1e-20,
            transition_steps=(config["NUM_UPDATES_DECAY"])
            * config["NUM_MINIBATCHES"]
            * config["NUM_EPOCHS"],
        )
        lr = lr_scheduler if config.get("LR_LINEAR_DECAY", False) else config["LR"]

        # INIT NETWORK AND OPTIMIZER
        network = QNetwork(
            action_dim=env.action_space(env_params).n,
            norm_type=config["NORM_TYPE"],
            norm_input=config.get("NORM_INPUT", False),
        )

        def create_agent(rng):
            init_x = jnp.zeros((1, *env.observation_space(env_params).shape))
            network_variables = network.init(rng, init_x, train=False)
            tx = optax.chain(
                optax.clip_by_global_norm(config["MAX_GRAD_NORM"]),
                optax.radam(learning_rate=lr),
            )

            train_state = CustomTrainState.create(
                apply_fn=network.apply,
                params=network_variables["params"],
                batch_stats=network_variables["batch_stats"],
                tx=tx,
            )
            return train_state

        rng, _rng = jax.random.split(rng)
        train_state = create_agent(rng)

        # TRAINING LOOP
        def _update_step(runner_state, unused):

            train_state, expl_state, test_metrics, rng = runner_state

            # SAMPLE PHASE
            def _step_env(carry, _):
                last_obs, env_state, rng = carry
                rng, rng_a, rng_s = jax.random.split(rng, 3)
                q_vals = network.apply(
                    {
                        "params": train_state.params,
                        "batch_stats": train_state.batch_stats,
                    },
                    last_obs,
                    train=False,
                )

                # different eps for each env
                _rngs = jax.random.split(rng_a, config["NUM_ENVS"])
                eps = jnp.full(config["NUM_ENVS"], eps_scheduler(train_state.n_updates))
                new_action = jax.vmap(eps_greedy_exploration)(_rngs, q_vals, eps)

                new_obs, new_env_state, reward, new_done, info = vmap_step(
                    config["NUM_ENVS"]
                )(rng_s, env_state, new_action)

                transition = Transition(
                    obs=last_obs,
                    action=new_action,
                    reward=config.get("REW_SCALE", 1)*reward,
                    done=new_done,
                    next_obs=new_obs,
                    q_val=q_vals,
                )
                return (new_obs, new_env_state, rng), (transition, info)

            # step the env
            rng, _rng = jax.random.split(rng)
            (*expl_state, rng), (transitions, infos) = jax.lax.scan(
                _step_env,
                (*expl_state, _rng),
                None,
                config["NUM_STEPS"],
            )
            expl_state = tuple(expl_state)

            train_state = train_state.replace(
                timesteps=train_state.timesteps
                + config["NUM_STEPS"] * config["NUM_ENVS"]
            )  # update timesteps count

            last_q = network.apply(
                {
                    "params": train_state.params,
                    "batch_stats": train_state.batch_stats,
                },
                transitions.next_obs[-1],
                train=False,
            )
            last_q = jnp.max(last_q, axis=-1)

            def _get_target(lambda_returns_and_next_q, transition):
                lambda_returns, next_q = lambda_returns_and_next_q
                target_bootstrap = (
                    transition.reward + config["GAMMA"] * (1 - transition.done) * next_q
                )
                delta = lambda_returns - next_q
                lambda_returns = (
                    target_bootstrap + config["GAMMA"] * config["LAMBDA"] * delta
                )
                lambda_returns = (
                    1 - transition.done
                ) * lambda_returns + transition.done * transition.reward
                next_q = jnp.max(transition.q_val, axis=-1)
                return (lambda_returns, next_q), lambda_returns

            last_q = last_q * (1 - transitions.done[-1])
            lambda_returns = transitions.reward[-1] + config["GAMMA"] * last_q
            _, targets = jax.lax.scan(
                _get_target,
                (lambda_returns, last_q),
                jax.tree_map(lambda x: x[:-1], transitions),
                reverse=True,
            )
            lambda_targets = jnp.concatenate((targets, lambda_returns[np.newaxis]))

            # NETWORKS UPDATE
            def _learn_epoch(carry, _):
                train_state, rng = carry

                def _learn_phase(carry, minibatch_and_target):

                    train_state, rng = carry
                    minibatch, target = minibatch_and_target

                    def _loss_fn(params):
                        q_vals, updates = network.apply(
                            {"params": params, "batch_stats": train_state.batch_stats},
                            minibatch.obs,
                            train=True,
                            mutable=["batch_stats"],
                        )  # (batch_size*2, num_actions)

                        chosen_action_qvals = jnp.take_along_axis(
                            q_vals,
                            jnp.expand_dims(minibatch.action, axis=-1),
                            axis=-1,
                        ).squeeze(axis=-1)

                        loss = 0.5 * jnp.square(chosen_action_qvals - target).mean()

                        return loss, (updates, chosen_action_qvals)

                    (loss, (updates, qvals)), grads = jax.value_and_grad(
                        _loss_fn, has_aux=True
                    )(train_state.params)
                    train_state = train_state.apply_gradients(grads=grads)
                    train_state = train_state.replace(
                        grad_steps=train_state.grad_steps + 1,
                        batch_stats=updates["batch_stats"],
                    )
                    return (train_state, rng), (loss, qvals)

                def preprocess_transition(x, rng):
                    x = x.reshape(
                        -1, *x.shape[2:]
                    )  # num_steps*num_envs (batch_size), ...
                    x = jax.random.permutation(rng, x)  # shuffle the transitions
                    x = x.reshape(
                        config["NUM_MINIBATCHES"], -1, *x.shape[1:]
                    )  # num_mini_updates, batch_size/num_mini_updates, ...
                    return x

                rng, _rng = jax.random.split(rng)
                minibatches = jax.tree_util.tree_map(
                    lambda x: preprocess_transition(x, _rng), transitions
                )  # num_actors*num_envs (batch_size), ...
                targets = jax.tree_map(
                    lambda x: preprocess_transition(x, _rng), lambda_targets
                )

                rng, _rng = jax.random.split(rng)
                (train_state, rng), (loss, qvals) = jax.lax.scan(
                    _learn_phase, (train_state, rng), (minibatches, targets)
                )

                return (train_state, rng), (loss, qvals)

            rng, _rng = jax.random.split(rng)
            (train_state, rng), (loss, qvals) = jax.lax.scan(
                _learn_epoch, (train_state, rng), None, config["NUM_EPOCHS"]
            )

            train_state = train_state.replace(n_updates=train_state.n_updates + 1)
            metrics = {
                "env_step": train_state.timesteps,
                "update_steps": train_state.n_updates,
                "env_frame": train_state.timesteps * env.observation_space(env_params).shape[-1],
                "grad_steps": train_state.grad_steps,
                "td_loss": loss.mean(),
                "qvals": qvals.mean(),
            }
            metrics.update({k: v.mean() for k, v in infos.items()})

            if config.get("TEST_DURING_TRAINING", False):
                rng, _rng = jax.random.split(rng)
                test_metrics = jax.lax.cond(
                    train_state.n_updates
                    % int(config["NUM_UPDATES"] * config["TEST_INTERVAL"])
                    == 0,
                    lambda _: get_test_metrics(train_state, _rng),
                    lambda _: test_metrics,
                    operand=None,
                )
                metrics.update({f"test_{k}": v for k, v in test_metrics.items()})

            # report on wandb if required
            if config["WANDB_MODE"] != "disabled":

                def callback(metrics, original_rng):
                    if config.get("WANDB_LOG_ALL_SEEDS", False):
                        metrics.update(
                            {
                                f"rng{int(original_rng)}/{k}": v
                                for k, v in metrics.items()
                            }
                        )
                    wandb.log(metrics, step=metrics["update_steps"])

                jax.debug.callback(callback, metrics, original_rng)

            runner_state = (train_state, tuple(expl_state), test_metrics, rng)

            return runner_state, metrics

        def get_test_metrics(train_state, rng):

            if not config.get("TEST_DURING_TRAINING", False):
                return None

            def _env_step(carry, _):
                env_state, last_obs, rng = carry
                rng, _rng = jax.random.split(rng)
                q_vals = network.apply(
                    {
                        "params": train_state.params,
                        "batch_stats": train_state.batch_stats,
                    },
                    last_obs,
                    train=False,
                )
                eps = jnp.full(config["TEST_NUM_ENVS"], config["EPS_TEST"])
                action = jax.vmap(eps_greedy_exploration)(
                    jax.random.split(_rng, config["TEST_NUM_ENVS"]), q_vals, eps
                )
                new_obs, new_env_state, reward, done, info = vmap_step(
                    config["TEST_NUM_ENVS"]
                )(_rng, env_state, action)
                return (new_env_state, new_obs, rng), info

            rng, _rng = jax.random.split(rng)
            init_obs, env_state = vmap_reset(config["TEST_NUM_ENVS"])(_rng)

            _, infos = jax.lax.scan(
                _env_step, (env_state, init_obs, _rng), None, config["TEST_NUM_STEPS"]
            )
            # return mean of done infos
            done_infos = jax.tree_map(
                lambda x: jnp.nanmean(
                    jnp.where(
                        infos["returned_episode"],
                        x,
                        jnp.nan,
                    )
                ),
                infos,
            )
            return done_infos

        rng, _rng = jax.random.split(rng)
        test_metrics = get_test_metrics(train_state, _rng)

        rng, _rng = jax.random.split(rng)
        expl_state = vmap_reset(config["NUM_ENVS"])(_rng)

        # train
        rng, _rng = jax.random.split(rng)
        runner_state = (train_state, expl_state, test_metrics, _rng)

        runner_state, metrics = jax.lax.scan(
            _update_step, runner_state, None, config["NUM_UPDATES"]
        )

        return {"runner_state": runner_state, "metrics": metrics}

    return train

# %%
config = {
    "TOTAL_TIMESTEPS": 1e7,
    "TOTAL_TIMESTEPS_DECAY": 1e7,
    "NUM_ENVS": 128,
    "NUM_STEPS": 32,
    "EPS_START": 1.0,
    "EPS_FINISH": 0.05,
    "EPS_DECAY": 0.1,
    "NUM_MINIBATCHES": 32,
    "NUM_EPOCHS": 2,
    "NORM_TYPE": "layer_norm",
    "LR": 0.0005,
    "MAX_GRAD_NORM": 10,
    "LR_LINEAR_DECAY": True,
    "GAMMA": 0.99,
    "LAMBDA": 0.65,

    # env specific
    "ENV_NAME": "Asterix-MinAtar",
    "ENV_KWARGS": {},

    # evaluation
    "TEST_DURING_TRAINING": True,
    "TEST_INTERVAL": 0.05,
    "TEST_NUM_ENVS": 128,
    "EPS_TEST": 0.0,

    # log
    "WANDB_MODE": "disabled",
}

# %%
import time

seed = 0
num_seeds = 3 # modify to run more runs in parallel (might affect time performances depending on the runtime)

rng = jax.random.PRNGKey(seed)

t0 = time.time()
rngs = jax.random.split(rng, num_seeds)
train_vjit = jax.jit(jax.vmap(make_train(config)))
outs = jax.block_until_ready(train_vjit(rngs))
print(f"Took {time.time()-t0} seconds to complete.")
# Out:
# /usr/local/lib/python3.11/dist-packages/jax/_src/ops/scatter.py:92: FutureWarning: scatter inputs have incompatible types: cannot safely cast value from dtype=int32 to dtype=bool with jax_numpy_dtype_promotion='standard'. In future JAX releases this will result in an error.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/jax/_src/ops/scatter.py:92: FutureWarning: scatter inputs have incompatible types: cannot safely cast value from dtype=int32 to dtype=bool with jax_numpy_dtype_promotion='standard'. In future JAX releases this will result in an error.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/jax/_src/ops/scatter.py:92: FutureWarning: scatter inputs have incompatible types: cannot safely cast value from dtype=int32 to dtype=bool with jax_numpy_dtype_promotion='standard'. In future JAX releases this will result in an error.
#   warnings.warn(
# <ipython-input-7-b0b89302f950>:394: DeprecationWarning: jax.tree_map is deprecated: use jax.tree.map (jax v0.4.25 or newer) or jax.tree_util.tree_map (any JAX version).
#   done_infos = jax.tree_map(
# <ipython-input-7-b0b89302f950>:248: DeprecationWarning: jax.tree_map is deprecated: use jax.tree.map (jax v0.4.25 or newer) or jax.tree_util.tree_map (any JAX version).
#   jax.tree_map(lambda x: x[:-1], transitions),
# <ipython-input-7-b0b89302f950>:304: DeprecationWarning: jax.tree_map is deprecated: use jax.tree.map (jax v0.4.25 or newer) or jax.tree_util.tree_map (any JAX version).
#   targets = jax.tree_map(
# <ipython-input-7-b0b89302f950>:394: DeprecationWarning: jax.tree_map is deprecated: use jax.tree.map (jax v0.4.25 or newer) or jax.tree_util.tree_map (any JAX version).
#   done_infos = jax.tree_map(
# <ipython-input-7-b0b89302f950>:248: DeprecationWarning: jax.tree_map is deprecated: use jax.tree.map (jax v0.4.25 or newer) or jax.tree_util.tree_map (any JAX version).
#   jax.tree_map(lambda x: x[:-1], transitions),
# <ipython-input-7-b0b89302f950>:304: DeprecationWarning: jax.tree_map is deprecated: use jax.tree.map (jax v0.4.25 or newer) or jax.tree_util.tree_map (any JAX version).
#   targets = jax.tree_map(
# <ipython-input-7-b0b89302f950>:394: DeprecationWarning: jax.tree_map is deprecated: use jax.tree.map (jax v0.4.25 or newer) or jax.tree_util.tree_map (any JAX version).
#   done_infos = jax.tree_map(
# Took 234.6776704788208 seconds to complete.

# %% [markdown]
# Let's plot the returns collected by the exploratory policy (eps-greedy) and the greedy policy tested during training for each seed used for training.

# %%
from matplotlib import pyplot as plt

for i in range(num_seeds):
  seed_metrics = jax.tree_map(lambda x: x[i], outs['metrics'])
  env_steps = seed_metrics['env_step']
  plt.plot(env_steps, seed_metrics['returned_episode_returns'], label=f'seed_{i}')
  plt.plot(env_steps, seed_metrics['test_returned_episode_returns'], label=f'test_seed_{i}')

plt.xlabel('steps')
plt.ylabel('returns')
plt.legend()
# Out:
# <ipython-input-24-fde86cf33b23>:4: DeprecationWarning: jax.tree_map is deprecated: use jax.tree.map (jax v0.4.25 or newer) or jax.tree_util.tree_map (any JAX version).
#   seed_metrics = jax.tree_map(lambda x: x[i], outs['metrics'])

# %% [markdown]
# # Pytorch training of PQN in Atari Pong
#
# Now let's now run PQN with Pytorch on a simple Atari game like Pong! In this case we will use the Cleanrl implementation: https://github.com/vwxyzjn/cleanrl/blob/master/cleanrl/pqn_atari_envpool.py
#
# Vectorization of Atari is done with Envpool and occurs on the CPU. In a modern workstation should take around 2 minutes. In Colab depending on the rentime should take about 8-9 minutes to obtain a good enough policy and about 10-12 to have an always wining agent. Mind that you can find the original and faster Jax-based implementation of PQN at https://github.com/mttga/purejaxql/blob/main/purejaxql/pqn_atari.py, which also provides an XLA Envpool interface for compiling the entire code (gpu-training and cpu-environment sampling) with Jax.

# %%
# !pip install gymnasium[atari]
# !pip install envpool
# !pip install tyro
# !pip install gym==0.23.1  # Because it is compatible with Recorder from pqn implementation
# Out:
# Requirement already satisfied: gymnasium[atari] in /usr/local/lib/python3.11/dist-packages (1.0.0)
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.11/dist-packages (from gymnasium[atari]) (1.26.4)
# Requirement already satisfied: cloudpickle>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from gymnasium[atari]) (3.1.1)
# Requirement already satisfied: typing-extensions>=4.3.0 in /usr/local/lib/python3.11/dist-packages (from gymnasium[atari]) (4.12.2)
# Requirement already satisfied: farama-notifications>=0.0.1 in /usr/local/lib/python3.11/dist-packages (from gymnasium[atari]) (0.0.4)
# Requirement already satisfied: ale-py>=0.9 in /usr/local/lib/python3.11/dist-packages (from gymnasium[atari]) (0.10.2)
# Requirement already satisfied: envpool in /usr/local/lib/python3.11/dist-packages (0.8.4)
# Requirement already satisfied: dm-env>=1.4 in /usr/local/lib/python3.11/dist-packages (from envpool) (1.6)
# Requirement already satisfied: gym>=0.18 in /usr/local/lib/python3.11/dist-packages (from envpool) (0.23.1)
# Requirement already satisfied: gymnasium>=0.26 in /usr/local/lib/python3.11/dist-packages (from envpool) (1.0.0)
# Requirement already satisfied: numpy>=1.19 in /usr/local/lib/python3.11/dist-packages (from envpool) (1.26.4)
# Requirement already satisfied: types-protobuf>=3.17.3 in /usr/local/lib/python3.11/dist-packages (from envpool) (5.29.1.20250208)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.11/dist-packages (from envpool) (4.12.2)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from envpool) (24.2)
# Requirement already satisfied: optree>=0.6.0 in /usr/local/lib/python3.11/dist-packages (from envpool) (0.14.0)
# Requirement already satisfied: absl-py in /usr/local/lib/python3.11/dist-packages (from dm-env>=1.4->envpool) (1.4.0)
# Requirement already satisfied: dm-tree in /usr/local/lib/python3.11/dist-packages (from dm-env>=1.4->envpool) (0.1.9)
# Requirement already satisfied: cloudpickle>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from gym>=0.18->envpool) (3.1.1)
# Requirement already satisfied: gym_notices>=0.0.4 in /usr/local/lib/python3.11/dist-packages (from gym>=0.18->envpool) (0.0.8)
# Requirement already satisfied: farama-notifications>=0.0.1 in /usr/local/lib/python3.11/dist-packages (from gymnasium>=0.26->envpool) (0.0.4)
# Requirement already satisfied: attrs>=18.2.0 in /usr/local/lib/python3.11/dist-packages (from dm-tree->dm-env>=1.4->envpool) (25.1.0)
# Requirement already satisfied: wrapt>=1.11.2 in /usr/local/lib/python3.11/dist-packages (from dm-tree->dm-env>=1.4->envpool) (1.17.2)
# Requirement already satisfied: tyro in /usr/local/lib/python3.11/dist-packages (0.9.16)
# Requirement already satisfied: docstring-parser>=0.15 in /usr/local/lib/python3.11/dist-packages (from tyro) (0.16)
# Requirement already satisfied: rich>=11.1.0 in /usr/local/lib/python3.11/dist-packages (from tyro) (13.9.4)
# Requirement already satisfied: shtab>=1.5.6 in /usr/local/lib/python3.11/dist-packages (from tyro) (1.7.1)
# Requirement already satisfied: typeguard>=4.0.0 in /usr/local/lib/python3.11/dist-packages (from tyro) (4.4.2)
# Requirement already satisfied: typing-extensions>=4.9.0 in /usr/local/lib/python3.11/dist-packages (from tyro) (4.12.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.11/dist-packages (from rich>=11.1.0->tyro) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.11/dist-packages (from rich>=11.1.0->tyro) (2.18.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.11/dist-packages (from markdown-it-py>=2.2.0->rich>=11.1.0->tyro) (0.1.2)
# Requirement already satisfied: gym==0.23.1 in /usr/local/lib/python3.11/dist-packages (0.23.1)
# Requirement already satisfied: numpy>=1.18.0 in /usr/local/lib/python3.11/dist-packages (from gym==0.23.1) (1.26.4)
# Requirement already satisfied: cloudpickle>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from gym==0.23.1) (3.1.1)
# Requirement already satisfied: gym_notices>=0.0.4 in /usr/local/lib/python3.11/dist-packages (from gym==0.23.1) (0.0.8)

# %% [markdown]
# Now we will use the [implementation from CleanRL](https://github.com/vwxyzjn/cleanrl/blob/master/cleanrl/pqn_atari_envpool.py) for running PQN on Atari's Pong using Pytorch.

# %%
# docs and experiment results can be found at https://docs.cleanrl.dev/rl-algorithms/pqn/#pqn_atari_envpoolpy
import os
import random
import time
from collections import deque
from dataclasses import dataclass

import envpool
import gym
import numpy as np
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.utils.tensorboard import SummaryWriter


@dataclass
class Args:
    exp_name: str = 'pqn_atari_envpool'
    """the name of this experiment"""
    seed: int = 1
    """seed of the experiment"""
    torch_deterministic: bool = True
    """if toggled, `torch.backends.cudnn.deterministic=False`"""
    cuda: bool = True
    """if toggled, cuda will be enabled by default"""
    track: bool = False
    """if toggled, this experiment will be tracked with Weights and Biases"""
    wandb_project_name: str = "cleanRL"
    """the wandb's project name"""
    wandb_entity: str = None
    """the entity (team) of wandb's project"""
    capture_video: bool = False
    """whether to capture videos of the agent performances (check out `videos` folder)"""

    # Algorithm specific arguments
    env_id: str = "Breakout-v5"
    """the id of the environment"""
    total_timesteps: int = 10000000
    """total timesteps of the experiments"""
    learning_rate: float = 2.5e-4
    """the learning rate of the optimizer"""
    num_envs: int = 8
    """the number of parallel game environments"""
    num_steps: int = 128
    """the number of steps to run in each environment per policy rollout"""
    anneal_lr: bool = True
    """Toggle learning rate annealing for policy and value networks"""
    gamma: float = 0.99
    """the discount factor gamma"""
    num_minibatches: int = 4
    """the number of mini-batches"""
    update_epochs: int = 4
    """the K epochs to update the policy"""
    max_grad_norm: float = 10.0
    """the maximum norm for the gradient clipping"""
    start_e: float = 1
    """the starting epsilon for exploration"""
    end_e: float = 0.01
    """the ending epsilon for exploration"""
    exploration_fraction: float = 0.10
    """the fraction of `total_timesteps` it takes from start_e to end_e"""
    q_lambda: float = 0.65
    """the lambda for the Q-Learning algorithm"""

    # to be filled in runtime
    batch_size: int = 0
    """the batch size (computed in runtime)"""
    minibatch_size: int = 0
    """the mini-batch size (computed in runtime)"""
    num_iterations: int = 0
    """the number of iterations (computed in runtime)"""


class RecordEpisodeStatistics(gym.Wrapper):
    def __init__(self, env, deque_size=100):
        super().__init__(env)
        self.num_envs = getattr(env, "num_envs", 1)
        self.episode_returns = None
        self.episode_lengths = None

    def reset(self, **kwargs):
        observations = super().reset(**kwargs)
        self.episode_returns = np.zeros(self.num_envs, dtype=np.float32)
        self.episode_lengths = np.zeros(self.num_envs, dtype=np.int32)
        self.lives = np.zeros(self.num_envs, dtype=np.int32)
        self.returned_episode_returns = np.zeros(self.num_envs, dtype=np.float32)
        self.returned_episode_lengths = np.zeros(self.num_envs, dtype=np.int32)
        return observations

    def step(self, action):
        observations, rewards, dones, infos = super().step(action)
        self.episode_returns += infos["reward"]
        self.episode_lengths += 1
        self.returned_episode_returns[:] = self.episode_returns
        self.returned_episode_lengths[:] = self.episode_lengths
        self.episode_returns *= 1 - infos["terminated"]
        self.episode_lengths *= 1 - infos["terminated"]
        infos["r"] = self.returned_episode_returns
        infos["l"] = self.returned_episode_lengths
        return (
            observations,
            rewards,
            dones,
            infos,
        )


def layer_init(layer, std=np.sqrt(2), bias_const=0.0):
    torch.nn.init.orthogonal_(layer.weight, std)
    torch.nn.init.constant_(layer.bias, bias_const)
    return layer


class QNetwork(nn.Module):
    def __init__(self, env):
        super().__init__()
        self.network = nn.Sequential(
            layer_init(nn.Conv2d(4, 32, 8, stride=4)),
            nn.LayerNorm([32, 20, 20]),
            nn.ReLU(),
            layer_init(nn.Conv2d(32, 64, 4, stride=2)),
            nn.LayerNorm([64, 9, 9]),
            nn.ReLU(),
            layer_init(nn.Conv2d(64, 64, 3, stride=1)),
            nn.LayerNorm([64, 7, 7]),
            nn.ReLU(),
            nn.Flatten(),
            layer_init(nn.Linear(3136, 512)),
            nn.LayerNorm(512),
            nn.ReLU(),
            layer_init(nn.Linear(512, env.single_action_space.n)),
        )

    def forward(self, x):
        return self.network(x / 255.0)


def linear_schedule(start_e: float, end_e: float, duration: int, t: int):
    slope = (end_e - start_e) / duration
    return max(slope * t + start_e, end_e)


def main(args):
    args.batch_size = int(args.num_envs * args.num_steps)
    args.minibatch_size = int(args.batch_size // args.num_minibatches)
    args.num_iterations = args.total_timesteps // args.batch_size
    run_name = f"{args.env_id}__{args.exp_name}__{args.seed}__{int(time.time())}"
    if args.track:
        import wandb

        wandb.init(
            project=args.wandb_project_name,
            entity=args.wandb_entity,
            sync_tensorboard=True,
            config=vars(args),
            name=run_name,
            monitor_gym=True,
            save_code=True,
        )
    writer = SummaryWriter(f"runs/{run_name}")
    writer.add_text(
        "hyperparameters",
        "|param|value|\n|-|-|\n%s" % ("\n".join([f"|{key}|{value}|" for key, value in vars(args).items()])),
    )

    # TRY NOT TO MODIFY: seeding
    random.seed(args.seed)
    np.random.seed(args.seed)
    torch.manual_seed(args.seed)
    torch.backends.cudnn.deterministic = args.torch_deterministic

    device = torch.device("cuda" if torch.cuda.is_available() and args.cuda else "cpu")

    # env setup
    envs = envpool.make(
        args.env_id,
        env_type="gym",
        num_envs=args.num_envs,
        episodic_life=True,
        reward_clip=True,
        seed=args.seed,
    )
    envs.num_envs = args.num_envs
    envs.single_action_space = envs.action_space
    envs.single_observation_space = envs.observation_space
    envs = RecordEpisodeStatistics(envs)
    assert isinstance(envs.action_space, gym.spaces.Discrete), "only discrete action space is supported"

    q_network = QNetwork(envs).to(device)
    optimizer = optim.RAdam(q_network.parameters(), lr=args.learning_rate)

    # ALGO Logic: Storage setup
    obs = torch.zeros((args.num_steps, args.num_envs) + envs.single_observation_space.shape).to(device)
    actions = torch.zeros((args.num_steps, args.num_envs) + envs.single_action_space.shape).to(device)
    rewards = torch.zeros((args.num_steps, args.num_envs)).to(device)
    dones = torch.zeros((args.num_steps, args.num_envs)).to(device)
    values = torch.zeros((args.num_steps, args.num_envs)).to(device)
    avg_returns = deque(maxlen=20)

    # TRY NOT TO MODIFY: start the game
    global_step = 0
    start_time = time.time()
    next_obs = torch.Tensor(envs.reset()).to(device)
    next_done = torch.zeros(args.num_envs).to(device)

    for iteration in range(1, args.num_iterations + 1):
        # Annealing the rate if instructed to do so.
        if args.anneal_lr:
            frac = 1.0 - (iteration - 1.0) / args.num_iterations
            lrnow = frac * args.learning_rate
            optimizer.param_groups[0]["lr"] = lrnow

        for step in range(0, args.num_steps):
            global_step += args.num_envs
            obs[step] = next_obs
            dones[step] = next_done

            epsilon = linear_schedule(args.start_e, args.end_e, args.exploration_fraction * args.total_timesteps, global_step)

            random_actions = torch.randint(0, envs.single_action_space.n, (args.num_envs,)).to(device)
            with torch.no_grad():
                q_values = q_network(next_obs)
                max_actions = torch.argmax(q_values, dim=1)
                values[step] = q_values[torch.arange(args.num_envs), max_actions].flatten()

            explore = torch.rand((args.num_envs,)).to(device) < epsilon
            action = torch.where(explore, random_actions, max_actions)
            actions[step] = action

            # TRY NOT TO MODIFY: execute the game and log data.
            next_obs, reward, next_done, info = envs.step(action.cpu().numpy())
            rewards[step] = torch.tensor(reward).to(device).view(-1)
            next_obs, next_done = torch.Tensor(next_obs).to(device), torch.Tensor(next_done).to(device)

            for idx, d in enumerate(next_done):
                if d and info["lives"][idx] == 0:
                    print(f"global_step={global_step}, episodic_return={info['r'][idx]}")
                    avg_returns.append(info["r"][idx])
                    writer.add_scalar("charts/avg_episodic_return", np.average(avg_returns), global_step)
                    writer.add_scalar("charts/episodic_return", info["r"][idx], global_step)
                    writer.add_scalar("charts/episodic_length", info["l"][idx], global_step)

        # Compute Q(lambda) targets
        with torch.no_grad():
            returns = torch.zeros_like(rewards).to(device)
            for t in reversed(range(args.num_steps)):
                if t == args.num_steps - 1:
                    next_value, _ = torch.max(q_network(next_obs), dim=-1)
                    nextnonterminal = 1.0 - next_done
                    returns[t] = rewards[t] + args.gamma * next_value * nextnonterminal
                else:
                    nextnonterminal = 1.0 - dones[t + 1]
                    next_value = values[t + 1]
                    returns[t] = rewards[t] + args.gamma * (
                        args.q_lambda * returns[t + 1] + (1 - args.q_lambda) * next_value * nextnonterminal
                    )

        # flatten the batch
        b_obs = obs.reshape((-1,) + envs.single_observation_space.shape)
        b_actions = actions.reshape((-1,) + envs.single_action_space.shape)
        b_returns = returns.reshape(-1)

        # Optimizing the Q-network
        b_inds = np.arange(args.batch_size)
        for epoch in range(args.update_epochs):
            np.random.shuffle(b_inds)
            for start in range(0, args.batch_size, args.minibatch_size):
                end = start + args.minibatch_size
                mb_inds = b_inds[start:end]

                old_val = q_network(b_obs[mb_inds]).gather(1, b_actions[mb_inds].unsqueeze(-1).long()).squeeze()
                loss = F.mse_loss(b_returns[mb_inds], old_val)

                # optimize the model
                optimizer.zero_grad()
                loss.backward()
                nn.utils.clip_grad_norm_(q_network.parameters(), args.max_grad_norm)
                optimizer.step()

        writer.add_scalar("losses/td_loss", loss, global_step)
        writer.add_scalar("losses/q_values", old_val.mean().item(), global_step)
        print("SPS:", int(global_step / (time.time() - start_time)))
        writer.add_scalar("charts/SPS", int(global_step / (time.time() - start_time)), global_step)

    envs.close()
    writer.close()

    # Record the agent's performance
    from moviepy.editor import ImageSequenceClip

    def record_agent_performance(q_network, env_id, num_episodes=1):
        output_path=env_id+".mp4"
        env = envpool.make(env_id, env_type="gym", num_envs=1)
        frames = []

        for episode in range(num_episodes):
            obs = env.reset()
            print(obs.shape)
            done = False

            while not done:
                # Assuming your agent has a predict method
                with torch.no_grad():
                    q_values = q_network(torch.Tensor(obs).to(device))
                    max_actions = torch.argmax(q_values, dim=1)
                # values[step] = q_values[torch.arange(args.num_envs), max_actions].flatten()
                random_actions = torch.randint(0, envs.single_action_space.n, (args.num_envs,)).to(device)
                explore = torch.rand((args.num_envs,)).to(device) < 0.01
                action = torch.where(explore, random_actions, max_actions)
                action = action.cpu().numpy().astype(np.int32)
                obs, reward,  done, info = env.step(action)
                frame = obs[0][0] # First frame of the four frames in the observation
                frame = np.stack([frame] * 3, axis=-1) # grayscale to RGB
                frame = np.uint8(frame * 255)
                frames.append(frame)

        clip = ImageSequenceClip(frames, fps=30)
        clip.write_videofile(output_path, fps=30)

        return output_path

    recorded_video = record_agent_performance(q_network, args.env_id, num_episodes=1)

    return q_network

# %%
# %%time
args = Args(
    env_id="Pong-v5",
    total_timesteps=1000000,
    num_envs=64,
    num_minibatches=32,
    seed=1
)

q_network = main(args)
# Out:
# SPS: 1009
# SPS: 1112
# SPS: 1103
# SPS: 1132
# SPS: 1127
# global_step=48512, episodic_return=-21.0
# global_step=48640, episodic_return=-21.0
# global_step=48832, episodic_return=-21.0
# SPS: 1127
# global_step=50240, episodic_return=-21.0
# global_step=50560, episodic_return=-21.0
# global_step=51520, episodic_return=-21.0
# global_step=51776, episodic_return=-21.0
# global_step=52480, episodic_return=-21.0
# global_step=52672, episodic_return=-21.0
# global_step=52736, episodic_return=-21.0
# global_step=53504, episodic_return=-20.0
# global_step=53696, episodic_return=-21.0
# global_step=53696, episodic_return=-21.0
# global_step=54336, episodic_return=-20.0
# global_step=54464, episodic_return=-21.0
# global_step=54592, episodic_return=-21.0
# global_step=54720, episodic_return=-20.0
# global_step=54976, episodic_return=-20.0
# global_step=55424, episodic_return=-20.0
# global_step=55552, episodic_return=-21.0
# global_step=55744, episodic_return=-21.0
# global_step=55744, episodic_return=-21.0
# global_step=56192, episodic_return=-21.0
# global_step=56192, episodic_return=-21.0
# global_step=56576, episodic_return=-21.0
# global_step=56576, episodic_return=-21.0
# global_step=56768, episodic_return=-21.0
# global_step=56896, episodic_return=-20.0
# global_step=57024, episodic_return=-20.0
# global_step=57216, episodic_return=-20.0
# SPS: 1138
# global_step=57792, episodic_return=-20.0
# global_step=57792, episodic_return=-20.0
# global_step=58112, episodic_return=-21.0
# global_step=58112, episodic_return=-21.0
# global_step=58176, episodic_return=-21.0
# global_step=58176, episodic_return=-21.0
# global_step=58688, episodic_return=-20.0
# global_step=58752, episodic_return=-20.0
# global_step=59136, episodic_return=-20.0
# global_step=59520, episodic_return=-20.0
# global_step=59520, episodic_return=-21.0
# global_step=59648, episodic_return=-20.0
# global_step=59904, episodic_return=-21.0
# global_step=60032, episodic_return=-21.0
# global_step=60352, episodic_return=-21.0
# global_step=60352, episodic_return=-20.0
# global_step=61120, episodic_return=-20.0
# global_step=61440, episodic_return=-21.0
# global_step=62912, episodic_return=-20.0
# global_step=63680, episodic_return=-21.0
# global_step=63744, episodic_return=-21.0
# SPS: 1126
# global_step=65728, episodic_return=-19.0
# global_step=66432, episodic_return=-19.0
# global_step=66432, episodic_return=-18.0
# global_step=66752, episodic_return=-20.0
# global_step=67648, episodic_return=-18.0
# global_step=67776, episodic_return=-19.0
# global_step=68096, episodic_return=-20.0
# global_step=68352, episodic_return=-19.0
# global_step=70400, episodic_return=-19.0
# global_step=70528, episodic_return=-19.0
# global_step=73728, episodic_return=-18.0
# SPS: 1136
# global_step=76032, episodic_return=-19.0
# SPS: 1130
# global_step=89408, episodic_return=-17.0
# SPS: 1139
# SPS: 1137
# global_step=102720, episodic_return=-21.0
# global_step=103104, episodic_return=-21.0
# global_step=103488, episodic_return=-21.0
# global_step=104064, episodic_return=-20.0
# global_step=104448, episodic_return=-21.0
# global_step=104896, episodic_return=-20.0
# global_step=105344, episodic_return=-21.0
# global_step=105856, episodic_return=-21.0
# SPS: 1134
# global_step=106880, episodic_return=-21.0
# global_step=107072, episodic_return=-21.0
# global_step=107136, episodic_return=-21.0
# global_step=108160, episodic_return=-21.0
# global_step=108224, episodic_return=-21.0
# global_step=108288, episodic_return=-21.0
# global_step=108800, episodic_return=-21.0
# global_step=108992, episodic_return=-21.0
# global_step=109376, episodic_return=-21.0
# global_step=109696, episodic_return=-21.0
# global_step=109952, episodic_return=-21.0
# global_step=110080, episodic_return=-21.0
# global_step=110208, episodic_return=-20.0
# global_step=110656, episodic_return=-20.0
# global_step=111424, episodic_return=-21.0
# global_step=111424, episodic_return=-20.0
# global_step=111616, episodic_return=-21.0
# global_step=112000, episodic_return=-21.0
# global_step=112128, episodic_return=-20.0
# global_step=112448, episodic_return=-21.0
# global_step=112448, episodic_return=-21.0
# global_step=112960, episodic_return=-19.0
# global_step=113472, episodic_return=-21.0
# global_step=113856, episodic_return=-21.0
# global_step=113984, episodic_return=-20.0
# global_step=114240, episodic_return=-21.0
# global_step=114624, episodic_return=-21.0
# SPS: 1138
# global_step=115136, episodic_return=-20.0
# global_step=116288, episodic_return=-21.0
# global_step=116608, episodic_return=-21.0
# global_step=116800, episodic_return=-20.0
# global_step=117056, episodic_return=-20.0
# global_step=118208, episodic_return=-20.0
# global_step=118336, episodic_return=-20.0
# global_step=118592, episodic_return=-20.0
# global_step=119040, episodic_return=-21.0
# global_step=119232, episodic_return=-19.0
# global_step=119360, episodic_return=-19.0
# global_step=119744, episodic_return=-20.0
# global_step=120000, episodic_return=-21.0
# global_step=121024, episodic_return=-21.0
# global_step=121984, episodic_return=-20.0
# global_step=122304, episodic_return=-21.0
# global_step=122432, episodic_return=-20.0
# SPS: 1132
# global_step=122944, episodic_return=-20.0
# global_step=123776, episodic_return=-21.0
# global_step=123968, episodic_return=-21.0
# global_step=124480, episodic_return=-21.0
# global_step=125312, episodic_return=-20.0
# global_step=127232, episodic_return=-20.0
# global_step=127936, episodic_return=-20.0
# global_step=128768, episodic_return=-20.0
# global_step=128832, episodic_return=-21.0
# global_step=129152, episodic_return=-21.0
# global_step=130304, episodic_return=-21.0
# SPS: 1137
# SPS: 1134
# global_step=144000, episodic_return=-21.0
# SPS: 1139
# global_step=155200, episodic_return=-21.0
# SPS: 1140
# global_step=156416, episodic_return=-21.0
# global_step=157696, episodic_return=-20.0
# global_step=158848, episodic_return=-21.0
# global_step=158848, episodic_return=-21.0
# global_step=158912, episodic_return=-20.0
# global_step=160448, episodic_return=-21.0
# global_step=160768, episodic_return=-21.0
# global_step=160832, episodic_return=-21.0
# global_step=162240, episodic_return=-21.0
# global_step=162368, episodic_return=-21.0
# global_step=162560, episodic_return=-20.0
# global_step=163328, episodic_return=-21.0
# global_step=163712, episodic_return=-21.0
# SPS: 1136
# global_step=164032, episodic_return=-21.0
# global_step=164224, episodic_return=-21.0
# global_step=164544, episodic_return=-20.0
# global_step=164992, episodic_return=-21.0
# global_step=165888, episodic_return=-21.0
# global_step=166400, episodic_return=-21.0
# global_step=166528, episodic_return=-21.0
# global_step=167424, episodic_return=-21.0
# global_step=167936, episodic_return=-21.0
# global_step=168384, episodic_return=-20.0
# global_step=169344, episodic_return=-20.0
# global_step=169408, episodic_return=-20.0
# global_step=169664, episodic_return=-20.0
# global_step=169792, episodic_return=-20.0
# global_step=169856, episodic_return=-21.0
# global_step=170560, episodic_return=-20.0
# global_step=171072, episodic_return=-21.0
# global_step=171200, episodic_return=-20.0
# global_step=171776, episodic_return=-20.0
# global_step=172032, episodic_return=-20.0
# SPS: 1139
# global_step=172416, episodic_return=-21.0
# global_step=172544, episodic_return=-20.0
# global_step=172672, episodic_return=-21.0
# global_step=175104, episodic_return=-21.0
# global_step=175360, episodic_return=-21.0
# global_step=175488, episodic_return=-20.0
# global_step=175488, episodic_return=-20.0
# global_step=175680, episodic_return=-21.0
# global_step=176000, episodic_return=-20.0
# global_step=176448, episodic_return=-21.0
# global_step=176576, episodic_return=-20.0
# global_step=177536, episodic_return=-20.0
# global_step=178112, episodic_return=-20.0
# global_step=178240, episodic_return=-20.0
# global_step=178688, episodic_return=-19.0
# global_step=178944, episodic_return=-21.0
# global_step=179520, episodic_return=-20.0
# global_step=179776, episodic_return=-21.0
# global_step=179904, episodic_return=-20.0
# SPS: 1135
# global_step=180288, episodic_return=-18.0
# global_step=180480, episodic_return=-20.0
# global_step=180480, episodic_return=-21.0
# global_step=180608, episodic_return=-20.0
# global_step=181440, episodic_return=-19.0
# global_step=181632, episodic_return=-21.0
# global_step=182016, episodic_return=-21.0
# global_step=182144, episodic_return=-21.0
# global_step=182656, episodic_return=-21.0
# global_step=183424, episodic_return=-21.0
# SPS: 1138
# global_step=196608, episodic_return=-21.0
# SPS: 1136
# SPS: 1139
# global_step=205248, episodic_return=-21.0
# global_step=206976, episodic_return=-21.0
# global_step=207808, episodic_return=-21.0
# SPS: 1140
# global_step=214016, episodic_return=-20.0
# global_step=215424, episodic_return=-20.0
# global_step=215616, episodic_return=-20.0
# global_step=215680, episodic_return=-21.0
# global_step=215872, episodic_return=-21.0
# global_step=216384, episodic_return=-20.0
# global_step=216512, episodic_return=-21.0
# global_step=216512, episodic_return=-21.0
# global_step=217088, episodic_return=-20.0
# global_step=217600, episodic_return=-21.0
# global_step=218048, episodic_return=-21.0
# global_step=218752, episodic_return=-21.0
# global_step=218944, episodic_return=-21.0
# global_step=219136, episodic_return=-21.0
# global_step=219136, episodic_return=-20.0
# global_step=219840, episodic_return=-21.0
# global_step=220032, episodic_return=-21.0
# global_step=220672, episodic_return=-21.0
# SPS: 1137
# global_step=221568, episodic_return=-21.0
# global_step=221952, episodic_return=-19.0
# global_step=222592, episodic_return=-20.0
# global_step=223232, episodic_return=-20.0
# global_step=224192, episodic_return=-20.0
# global_step=225152, episodic_return=-21.0
# global_step=225408, episodic_return=-21.0
# global_step=225536, episodic_return=-21.0
# global_step=225600, episodic_return=-20.0
# global_step=226176, episodic_return=-20.0
# global_step=226368, episodic_return=-21.0
# global_step=226368, episodic_return=-20.0
# global_step=226432, episodic_return=-20.0
# global_step=228096, episodic_return=-21.0
# global_step=228160, episodic_return=-20.0
# global_step=228736, episodic_return=-20.0
# global_step=228864, episodic_return=-20.0
# global_step=228992, episodic_return=-20.0
# global_step=229312, episodic_return=-21.0
# SPS: 1139
# global_step=230144, episodic_return=-20.0
# global_step=230272, episodic_return=-20.0
# global_step=230272, episodic_return=-21.0
# global_step=230272, episodic_return=-19.0
# global_step=230464, episodic_return=-21.0
# global_step=230592, episodic_return=-19.0
# global_step=231680, episodic_return=-21.0
# global_step=232192, episodic_return=-21.0
# global_step=234112, episodic_return=-21.0
# global_step=235520, episodic_return=-20.0
# global_step=236800, episodic_return=-21.0
# global_step=237056, episodic_return=-20.0
# SPS: 1136
# global_step=239104, episodic_return=-21.0
# global_step=240000, episodic_return=-21.0
# global_step=240384, episodic_return=-21.0
# global_step=240896, episodic_return=-20.0
# global_step=241280, episodic_return=-21.0
# global_step=242560, episodic_return=-18.0
# global_step=244032, episodic_return=-18.0
# SPS: 1139
# global_step=247232, episodic_return=-15.0
# global_step=247936, episodic_return=-19.0
# SPS: 1137
# global_step=254656, episodic_return=-19.0
# global_step=255424, episodic_return=-17.0
# SPS: 1140
# global_step=266944, episodic_return=-19.0
# SPS: 1141
# global_step=271552, episodic_return=-20.0
# global_step=273920, episodic_return=-21.0
# SPS: 1139
# global_step=280000, episodic_return=-21.0
# global_step=285120, episodic_return=-17.0
# SPS: 1141
# global_step=288768, episodic_return=-21.0
# global_step=288768, episodic_return=-20.0
# global_step=289024, episodic_return=-19.0
# global_step=289216, episodic_return=-20.0
# global_step=289216, episodic_return=-20.0
# global_step=289280, episodic_return=-20.0
# global_step=289472, episodic_return=-17.0
# global_step=291008, episodic_return=-19.0
# global_step=291392, episodic_return=-20.0
# global_step=291776, episodic_return=-19.0
# global_step=292416, episodic_return=-20.0
# global_step=292480, episodic_return=-18.0
# global_step=292608, episodic_return=-19.0
# global_step=292672, episodic_return=-17.0
# global_step=293312, episodic_return=-19.0
# global_step=293440, episodic_return=-20.0
# global_step=294016, episodic_return=-19.0
# global_step=294912, episodic_return=-21.0
# SPS: 1139
# global_step=295296, episodic_return=-21.0
# global_step=296448, episodic_return=-18.0
# global_step=296832, episodic_return=-17.0
# global_step=296896, episodic_return=-16.0
# global_step=297472, episodic_return=-18.0
# global_step=298624, episodic_return=-19.0
# global_step=298816, episodic_return=-21.0
# global_step=298816, episodic_return=-17.0
# global_step=299584, episodic_return=-20.0
# global_step=300864, episodic_return=-17.0
# global_step=301184, episodic_return=-19.0
# global_step=301824, episodic_return=-18.0
# global_step=302080, episodic_return=-17.0
# global_step=302208, episodic_return=-19.0
# global_step=302912, episodic_return=-17.0
# SPS: 1141
# global_step=303680, episodic_return=-19.0
# global_step=304576, episodic_return=-20.0
# global_step=305920, episodic_return=-21.0
# global_step=306816, episodic_return=-16.0
# global_step=307008, episodic_return=-16.0
# global_step=308224, episodic_return=-15.0
# global_step=309440, episodic_return=-18.0
# global_step=311104, episodic_return=-19.0
# SPS: 1139
# global_step=312256, episodic_return=-20.0
# global_step=313408, episodic_return=-14.0
# global_step=315520, episodic_return=-16.0
# global_step=316800, episodic_return=-19.0
# global_step=317248, episodic_return=-15.0
# global_step=317504, episodic_return=-20.0
# global_step=319168, episodic_return=-21.0
# SPS: 1140
# global_step=319936, episodic_return=-18.0
# global_step=321984, episodic_return=-20.0
# global_step=322112, episodic_return=-16.0
# global_step=322496, episodic_return=-16.0
# global_step=322560, episodic_return=-21.0
# global_step=323968, episodic_return=-18.0
# global_step=325184, episodic_return=-15.0
# SPS: 1141
# global_step=329664, episodic_return=-14.0
# global_step=332288, episodic_return=-14.0
# SPS: 1139
# global_step=336640, episodic_return=-12.0
# SPS: 1141
# global_step=344640, episodic_return=-12.0
# global_step=346304, episodic_return=-21.0
# global_step=348032, episodic_return=-20.0
# SPS: 1139
# global_step=355968, episodic_return=-20.0
# SPS: 1141
# global_step=361472, episodic_return=-18.0
# global_step=366208, episodic_return=-20.0
# global_step=368384, episodic_return=-20.0
# SPS: 1140
# global_step=370944, episodic_return=-18.0
# global_step=371200, episodic_return=-20.0
# global_step=372352, episodic_return=-12.0
# global_step=373184, episodic_return=-19.0
# global_step=374656, episodic_return=-19.0
# SPS: 1140
# global_step=376896, episodic_return=-19.0
# global_step=378048, episodic_return=-20.0
# global_step=378240, episodic_return=-21.0
# global_step=380160, episodic_return=-19.0
# global_step=383744, episodic_return=-15.0
# global_step=383872, episodic_return=-19.0
# global_step=384832, episodic_return=-18.0
# SPS: 1142
# global_step=387840, episodic_return=-18.0
# global_step=387968, episodic_return=-19.0
# global_step=388352, episodic_return=-13.0
# global_step=389568, episodic_return=-17.0
# global_step=390976, episodic_return=-19.0
# global_step=391808, episodic_return=-14.0
# global_step=391936, episodic_return=-20.0
# global_step=392384, episodic_return=-12.0
# SPS: 1140
# global_step=393792, episodic_return=-13.0
# global_step=395520, episodic_return=-19.0
# global_step=395520, episodic_return=-15.0
# global_step=396544, episodic_return=-13.0
# global_step=397184, episodic_return=-15.0
# global_step=398080, episodic_return=-16.0
# global_step=399232, episodic_return=-14.0
# global_step=400640, episodic_return=-18.0
# SPS: 1142
# global_step=402176, episodic_return=-17.0
# global_step=405760, episodic_return=-13.0
# global_step=408256, episodic_return=-19.0
# global_step=408512, episodic_return=-17.0
# global_step=408768, episodic_return=-16.0
# global_step=409088, episodic_return=-13.0
# SPS: 1140
# global_step=412096, episodic_return=-17.0
# global_step=412480, episodic_return=-16.0
# global_step=412672, episodic_return=-15.0
# SPS: 1141
# global_step=417920, episodic_return=-11.0
# global_step=420992, episodic_return=-14.0
# global_step=422016, episodic_return=-17.0
# global_step=422528, episodic_return=-16.0
# global_step=423616, episodic_return=-10.0
# global_step=425920, episodic_return=-10.0
# SPS: 1140
# global_step=426560, episodic_return=-12.0
# SPS: 1141
# global_step=434432, episodic_return=-18.0
# global_step=435328, episodic_return=-10.0
# global_step=435584, episodic_return=-10.0
# global_step=437696, episodic_return=-13.0
# global_step=440256, episodic_return=-10.0
# global_step=440384, episodic_return=-11.0
# global_step=440384, episodic_return=-13.0
# SPS: 1142
# global_step=442688, episodic_return=-10.0
# global_step=442944, episodic_return=-10.0
# global_step=445184, episodic_return=-12.0
# global_step=448960, episodic_return=-15.0
# SPS: 1141
# global_step=451200, episodic_return=-13.0
# global_step=455488, episodic_return=-11.0
# global_step=457792, episodic_return=-17.0
# SPS: 1142
# global_step=462016, episodic_return=-13.0
# global_step=462784, episodic_return=-12.0
# SPS: 1141
# global_step=470400, episodic_return=-12.0
# SPS: 1142
# global_step=476800, episodic_return=-6.0
# global_step=481664, episodic_return=-17.0
# SPS: 1142
# global_step=486656, episodic_return=-15.0
# global_step=487040, episodic_return=-13.0
# global_step=487936, episodic_return=-13.0
# global_step=490048, episodic_return=-13.0
# SPS: 1142
# global_step=492800, episodic_return=-12.0
# global_step=497792, episodic_return=-11.0
# SPS: 1143
# global_step=503808, episodic_return=-12.0
# global_step=507904, episodic_return=-11.0
# SPS: 1142
# global_step=508224, episodic_return=-13.0
# global_step=509568, episodic_return=-13.0
# global_step=511360, episodic_return=-12.0
# global_step=513280, episodic_return=-9.0
# global_step=514368, episodic_return=-9.0
# SPS: 1143
# global_step=519296, episodic_return=-11.0
# global_step=520448, episodic_return=-9.0
# global_step=521920, episodic_return=-11.0
# global_step=522944, episodic_return=-14.0
# SPS: 1142
# global_step=527488, episodic_return=-10.0
# global_step=527488, episodic_return=-10.0
# global_step=528640, episodic_return=-9.0
# global_step=530112, episodic_return=-10.0
# global_step=531584, episodic_return=-6.0
# global_step=532096, episodic_return=-11.0
# SPS: 1143
# global_step=535232, episodic_return=-9.0
# global_step=536576, episodic_return=-14.0
# global_step=537408, episodic_return=-12.0
# global_step=538304, episodic_return=-14.0
# global_step=540480, episodic_return=-9.0
# SPS: 1142
# global_step=541952, episodic_return=-9.0
# global_step=542784, episodic_return=-9.0
# global_step=545536, episodic_return=-8.0
# global_step=548672, episodic_return=-7.0
# SPS: 1142
# global_step=555776, episodic_return=-4.0
# global_step=555968, episodic_return=-9.0
# SPS: 1144
# global_step=557376, episodic_return=-13.0
# global_step=557760, episodic_return=-4.0
# global_step=559552, episodic_return=-12.0
# global_step=560256, episodic_return=-5.0
# global_step=560832, episodic_return=-10.0
# SPS: 1142
# SPS: 1144
# global_step=574592, episodic_return=3.0
# global_step=575424, episodic_return=-10.0
# SPS: 1143
# global_step=582528, episodic_return=-6.0
# global_step=589056, episodic_return=10.0
# SPS: 1144
# global_step=590976, episodic_return=6.0
# global_step=591552, episodic_return=2.0
# global_step=592704, episodic_return=-6.0
# global_step=592832, episodic_return=1.0
# global_step=596928, episodic_return=1.0
# global_step=597120, episodic_return=8.0
# SPS: 1143
# global_step=598208, episodic_return=7.0
# global_step=600384, episodic_return=12.0
# global_step=605248, episodic_return=-1.0
# SPS: 1142
# global_step=608960, episodic_return=4.0
# global_step=613120, episodic_return=2.0
# global_step=613440, episodic_return=4.0
# SPS: 1143
# global_step=617088, episodic_return=7.0
# global_step=620160, episodic_return=5.0
# global_step=620352, episodic_return=5.0
# global_step=621888, episodic_return=1.0
# SPS: 1142
# global_step=625344, episodic_return=12.0
# global_step=629632, episodic_return=9.0
# global_step=629824, episodic_return=-8.0
# SPS: 1143
# global_step=634496, episodic_return=3.0
# global_step=634688, episodic_return=17.0
# global_step=638784, episodic_return=-12.0
# SPS: 1142
# global_step=639360, episodic_return=10.0
# global_step=641408, episodic_return=12.0
# global_step=642560, episodic_return=16.0
# global_step=643200, episodic_return=4.0
# global_step=644160, episodic_return=5.0
# global_step=644928, episodic_return=16.0
# global_step=645440, episodic_return=18.0
# global_step=645888, episodic_return=7.0
# global_step=646080, episodic_return=6.0
# global_step=646912, episodic_return=12.0
# SPS: 1143
# global_step=650240, episodic_return=-1.0
# global_step=650816, episodic_return=18.0
# global_step=651904, episodic_return=17.0
# SPS: 1142
# global_step=656704, episodic_return=2.0
# global_step=657408, episodic_return=10.0
# global_step=658432, episodic_return=11.0
# SPS: 1142
# global_step=664128, episodic_return=10.0
# global_step=664512, episodic_return=20.0
# global_step=665792, episodic_return=13.0
# global_step=669824, episodic_return=13.0
# global_step=669824, episodic_return=11.0
# global_step=670016, episodic_return=10.0
# global_step=670656, episodic_return=19.0
# SPS: 1142
# global_step=672000, episodic_return=19.0
# global_step=672832, episodic_return=9.0
# global_step=678656, episodic_return=12.0
# global_step=678912, episodic_return=12.0
# global_step=679872, episodic_return=18.0
# SPS: 1141
# global_step=680640, episodic_return=12.0
# global_step=683072, episodic_return=7.0
# global_step=684160, episodic_return=11.0
# global_step=684992, episodic_return=10.0
# SPS: 1142
# global_step=688576, episodic_return=14.0
# global_step=692096, episodic_return=13.0
# global_step=692480, episodic_return=8.0
# SPS: 1141
# global_step=702784, episodic_return=7.0
# global_step=703552, episodic_return=16.0
# SPS: 1141
# global_step=706176, episodic_return=8.0
# global_step=707136, episodic_return=9.0
# SPS: 1141
# global_step=713344, episodic_return=16.0
# global_step=715520, episodic_return=17.0
# global_step=715840, episodic_return=10.0
# SPS: 1140
# global_step=723136, episodic_return=16.0
# global_step=724608, episodic_return=18.0
# global_step=725184, episodic_return=17.0
# global_step=726848, episodic_return=13.0
# global_step=726912, episodic_return=18.0
# global_step=727360, episodic_return=12.0
# SPS: 1141
# global_step=731264, episodic_return=14.0
# global_step=733120, episodic_return=14.0
# global_step=733376, episodic_return=18.0
# global_step=733952, episodic_return=20.0
# global_step=735104, episodic_return=17.0
# global_step=736320, episodic_return=18.0
# global_step=737152, episodic_return=10.0
# SPS: 1140
# global_step=741888, episodic_return=17.0
# global_step=743296, episodic_return=20.0
# SPS: 1141
# global_step=747520, episodic_return=6.0
# global_step=750144, episodic_return=20.0
# global_step=750784, episodic_return=20.0
# global_step=753280, episodic_return=14.0
# SPS: 1140
# global_step=755456, episodic_return=17.0
# global_step=756096, episodic_return=19.0
# global_step=759680, episodic_return=16.0
# global_step=761664, episodic_return=18.0
# SPS: 1140
# global_step=762176, episodic_return=17.0
# global_step=763648, episodic_return=14.0
# SPS: 1140
# global_step=771264, episodic_return=16.0
# global_step=773696, episodic_return=17.0
# global_step=774656, episodic_return=14.0
# global_step=775104, episodic_return=20.0
# global_step=776704, episodic_return=20.0
# global_step=776768, episodic_return=12.0
# SPS: 1140
# global_step=779584, episodic_return=13.0
# global_step=781696, episodic_return=20.0
# global_step=782784, episodic_return=13.0
# global_step=784128, episodic_return=12.0
# global_step=784576, episodic_return=20.0
# global_step=785664, episodic_return=18.0
# SPS: 1140
# global_step=786944, episodic_return=12.0
# global_step=787264, episodic_return=1.0
# global_step=787776, episodic_return=15.0
# global_step=789184, episodic_return=17.0
# global_step=793216, episodic_return=12.0
# SPS: 1139
# global_step=795072, episodic_return=19.0
# global_step=795648, episodic_return=18.0
# global_step=797184, episodic_return=18.0
# global_step=797568, episodic_return=15.0
# global_step=798592, episodic_return=16.0
# global_step=800320, episodic_return=17.0
# global_step=802752, episodic_return=20.0
# SPS: 1140
# global_step=803584, episodic_return=16.0
# global_step=804672, episodic_return=19.0
# global_step=805312, episodic_return=19.0
# SPS: 1139
# global_step=812096, episodic_return=15.0
# global_step=812992, episodic_return=20.0
# global_step=813824, episodic_return=20.0
# global_step=814464, episodic_return=8.0
# SPS: 1139
# global_step=824128, episodic_return=12.0
# SPS: 1140
# global_step=828160, episodic_return=9.0
# global_step=829312, episodic_return=21.0
# SPS: 1139
# global_step=836224, episodic_return=20.0
# global_step=838144, episodic_return=20.0
# global_step=839872, episodic_return=14.0
# global_step=840064, episodic_return=20.0
# global_step=840192, episodic_return=20.0
# global_step=841792, episodic_return=19.0
# global_step=842048, episodic_return=18.0
# SPS: 1140
# global_step=844672, episodic_return=18.0
# global_step=845952, episodic_return=12.0
# global_step=846208, episodic_return=10.0
# global_step=846848, episodic_return=21.0
# global_step=848064, episodic_return=21.0
# global_step=849152, episodic_return=14.0
# SPS: 1139
# global_step=853568, episodic_return=18.0
# global_step=855040, episodic_return=16.0
# SPS: 1140
# global_step=860416, episodic_return=17.0
# global_step=860672, episodic_return=20.0
# global_step=861120, episodic_return=20.0
# global_step=861248, episodic_return=2.0
# global_step=863040, episodic_return=14.0
# SPS: 1140
# global_step=869056, episodic_return=20.0
# global_step=870400, episodic_return=15.0
# SPS: 1139
# global_step=877952, episodic_return=18.0
# global_step=879296, episodic_return=18.0
# global_step=880640, episodic_return=16.0
# global_step=880896, episodic_return=20.0
# global_step=881152, episodic_return=15.0
# global_step=881408, episodic_return=10.0
# global_step=881600, episodic_return=20.0
# global_step=881600, episodic_return=17.0
# global_step=883968, episodic_return=20.0
# global_step=884288, episodic_return=21.0
# SPS: 1140
# global_step=885376, episodic_return=20.0
# global_step=886144, episodic_return=15.0
# global_step=892096, episodic_return=21.0
# SPS: 1139
# global_step=893120, episodic_return=18.0
# global_step=893184, episodic_return=19.0
# global_step=896192, episodic_return=20.0
# global_step=896640, episodic_return=19.0
# global_step=897536, episodic_return=19.0
# global_step=897792, episodic_return=19.0
# global_step=900480, episodic_return=19.0
# SPS: 1140
# global_step=902144, episodic_return=20.0
# global_step=908736, episodic_return=17.0
# SPS: 1139
# global_step=911104, episodic_return=19.0
# global_step=911488, episodic_return=20.0
# global_step=912064, episodic_return=20.0
# global_step=912384, episodic_return=11.0
# global_step=915840, episodic_return=17.0
# global_step=916544, episodic_return=19.0
# global_step=917056, episodic_return=18.0
# SPS: 1140
# global_step=919744, episodic_return=20.0
# global_step=920704, episodic_return=16.0
# global_step=923200, episodic_return=18.0
# global_step=923776, episodic_return=12.0
# SPS: 1140
# global_step=930496, episodic_return=19.0
# global_step=933312, episodic_return=15.0
# SPS: 1139
# global_step=936064, episodic_return=20.0
# global_step=938816, episodic_return=18.0
# global_step=939200, episodic_return=12.0
# SPS: 1140
# global_step=945024, episodic_return=17.0
# global_step=945856, episodic_return=11.0
# global_step=946752, episodic_return=20.0
# global_step=949760, episodic_return=21.0
# SPS: 1140
# global_step=950720, episodic_return=20.0
# global_step=950848, episodic_return=20.0
# global_step=952896, episodic_return=15.0
# global_step=954240, episodic_return=20.0
# global_step=955712, episodic_return=15.0
# global_step=956864, episodic_return=18.0
# global_step=957568, episodic_return=18.0
# global_step=958400, episodic_return=20.0
# SPS: 1140
# global_step=960960, episodic_return=20.0
# global_step=962304, episodic_return=20.0
# global_step=965952, episodic_return=18.0
# SPS: 1140
# global_step=968576, episodic_return=18.0
# global_step=974016, episodic_return=20.0
# SPS: 1140
# global_step=979392, episodic_return=17.0
# global_step=979520, episodic_return=18.0
# global_step=981952, episodic_return=11.0
# global_step=982272, episodic_return=18.0
# SPS: 1140
# global_step=986752, episodic_return=15.0
# SPS: 1140
# global_step=992256, episodic_return=20.0
# global_step=993280, episodic_return=20.0
# global_step=994304, episodic_return=15.0
# global_step=994624, episodic_return=18.0
# global_step=994816, episodic_return=20.0
# global_step=994944, episodic_return=20.0
# global_step=995392, episodic_return=19.0
# global_step=996800, episodic_return=19.0
# global_step=998400, episodic_return=18.0
# SPS: 1141
# (1, 4, 84, 84)
# Moviepy - Building video Pong-v5.mp4.
# Moviepy - Writing video Pong-v5.mp4
# Moviepy - Done !
# Moviepy - video ready Pong-v5.mp4
# CPU times: user 22min 56s, sys: 4.91 s, total: 23min 1s
# Wall time: 14min 52s

# %% [markdown]
# We can visualize the trained agent here below. Notice that the frames you see are exactly the ones that the program sees after the Wrapping of the environment (B&W, reduced dimension screen etc).

# %%
from IPython.display import HTML
from base64 import b64encode
mp4 = open('Pong-v5.mp4','rb').read()
data_url = "data:video/mp4;base64," + b64encode(mp4).decode()
HTML("""
<video width=400 controls>
      <source src="%s" type="video/mp4">
</video>
""" % data_url)
# Out:
# <video width=400 controls>
#       <source src="data:video/mp4;base64,..." type="video/mp4">
# </video>
